# %%
import math
import matplotlib.pyplot as plt

# %% [markdown]
# ### First we define the variables

# %% [markdown]
# ##### For convenience, we set the background temperature to T = 0.
# ##### We set A = 1/(2*squareroot(Pi*K)) for reasons that will become clear.
# ##### We set K = 1 for simplicity, but this could work for any particular value of K, depending on material.

# %%
def temperature(x,t):
    T = (1/2*math.sqrt(math.pi))*math.exp(-x**2/(4*t))
    return T

# %% [markdown]
# Now, we graph this function with the Values of T on the y-axis and the values of x on the x-axis. We do this for different values of t. We are going to take increments of x to do this, but just choose a few values of t to make it simpler.

# %%
r=-14

x=[]

while r<14:
    x.append(r)
    r=r+0.05

# %%
T_at_very_small_t = []

for i in range(0,len(x)):
    T=temperature(x[i], 0.001)
    T_at_very_small_t.append(T)

# %%
plt.plot(x,T_at_very_small_t)
plt.xlabel('x')
plt.ylabel('T') 
plt.xlim([-10,10])
plt.ylim([0,2])
plt.savefig('a1q2.png')
plt.show() 
plt.close()

# %%
T_at_medium_t = []

for i in range(0,len(x)):
    T=temperature(x[i], 1)
    T_at_medium_t.append(T)

# %%
plt.plot(x,T_at_medium_t)
plt.xlabel('x')
plt.ylabel('T')
plt.xlim([-10,10])
plt.ylim([0,2])
plt.savefig('a1q2.png')
plt.show() 
plt.close()

# %%
T_at_big_t = []

for i in range(0,len(x)):
    T=temperature(x[i], 5)
    T_at_big_t.append(T)

# %%
plt.plot(x,T_at_big_t)
plt.xlabel('x')
plt.ylabel('T')
plt.xlim([-11,11])
plt.ylim([0,2])
plt.savefig('a1q2.png')
plt.show() 
plt.close()

# %% [markdown]
# The physical meaning of this is that at a very small time, or in the limit t --> 0, all of the energy will be focused on one point. If it is found at the origin, it will still be highly concentrated around that point at a very small t. Then for the second graph, some time has passed and the curve starts to spread out as the heat flows through the rod and is more evenly spread. Then, for large t, or in the limit t --> infinity, the curve should be
